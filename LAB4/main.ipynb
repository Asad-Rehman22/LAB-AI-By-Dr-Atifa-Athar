# %%
 
    class node
    def_init_(self,state,parent,actions,TotalCost)-> None:
        self.state=state
        self.parent=parent
        self.actions=actions
        self.TotalCost=TotalCost
  
 Graph= {
    
    "S":node("S",None,["d","e","p"],None)
    "d":node("d",None,["b","c"],None)
    "b":node("b",None,["a"],None)
    "c":node("c",None,["a"],None)
    "a":node("a",None,[],None)
    "e":node("e",None,["h"],None)
    "h":node("h",None,["r"],None)
    "p":node("S",None,["q"],None)
    "q":node("q",None,[],None)
    "r":node("r",None,["f"],None)
    "f":node("f",None,["G"],None)
    "G":node("G",None,[],None)
      
 }
    Queue=[]
    path=[]
    front=0
    rear=-1
    def BFS(S_node)
       adj_node=Graph[S_node].parent
        path.append(S_node)
        print(adj_node)
    for node in adj_node:
        Queue.insert(front,node)
        front+=1
    for node in S_node:
        Queue.pop(rear,node)
        rear+=1
    for node in Queue:
        Queue.remove(rear,node)
        path.append(node)
    
    print(path)
    
    
        
 
     initialState='D'
     goalState='F'
    front=[initialState]
    explored=[]
        
    def bfs()
        while len(front)!=0:
             current_node=front.pop(0)
            explored.append(node)
             if child in not in front and child not be explored:
                    graph[child].parent=currentNode
                if graph[child].state=goalState
                  print("goal found")
                    reurn True
